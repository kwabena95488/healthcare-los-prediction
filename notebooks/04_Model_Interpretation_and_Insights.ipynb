# %% [raw]
# # Healthcare Length of Stay - Model Interpretation & Business Insights
#
# This notebook focuses on interpreting trained models and extracting actionable business insights from the healthcare length of stay prediction system.
#
# ## Objectives
#
# 1. **Model Interpretation** - Understand how models make predictions
# 2. **Feature Importance Analysis** - Identify the most important factors
# 3. **SHAP Analysis** - Detailed explanation of individual predictions
# 4. **Model Comparison** - Compare different models' behavior and performance
# 5. **Business Insights** - Extract actionable insights for healthcare management
# 6. **Recommendations** - Provide data-driven recommendations
#
# This notebook assumes you have already trained models using the previous notebooks.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
import sys
from pathlib import Path
from typing import Dict, List, Any, Optional
import joblib

# Machine learning and interpretation libraries
import shap
from sklearn.inspection import permutation_importance
from sklearn.metrics import classification_report, confusion_matrix
import lime
from lime import lime_tabular

# Plotting configuration
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
warnings.filterwarnings('ignore')

# Add src to path for imports
sys.path.append(str(Path.cwd().parent))

# Import custom modules
from src.utils.config import load_config
from src.data.make_dataset import load_raw_data
from src.evaluation.interpretability import explain_model_predictions, analyze_feature_importance
from src.evaluation.model_comparison import compare_model_performance
from src.visualization.model_plots import (
    plot_feature_importance, plot_shap_summary, 
    plot_model_comparison, plot_prediction_analysis
)

print("✅ Libraries imported successfully!")

# Configure SHAP
shap.initjs()

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
plt.rcParams['figure.figsize'] = (12, 8)
